# %% [markdown]
# <a href="https://colab.research.google.com/github/t4t14n4-hub/Desafios-personales-/blob/main/Calculo_de_%C3%A1rea_de_rectangulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mediante este programa podras determinar el area de cualquier rectangulo")
ancho = numero1
largo = numero2




numero1 = int(input("¿Cuál es el ancho?: "))
numero2 = int(input("¿Cuál es el largo?: "))

area = numero1 * numero2

print(f"{numero1} * {numero2} = {area}")
print(f"El área del rectangulo es: {area}")
